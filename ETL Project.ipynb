# %%
import pandas as pd
import sqlalchemy

# %%
agents_df = pd.read_csv('Resources/agents.csv')
agencies_df = pd.read_csv('Resources/agencies.csv')
artists_df = pd.read_csv('Resources/artists.csv')
bands_df = pd.read_csv('Resources/bandsintown.csv')

# %%
agents_df
# Out:
#                   First                      Title    Phone Number  \
# 0             Rob Light  Worldwide - Head of Music  (424) 288 2000
# 1          Darryl Eaton      Co-Head of N. America  (424) 288 2000
# 2           Rick Roskin      Co-Head of N. America  (424) 288 2000
# 3            Mitch Rose      Co-Head of N. America  (424) 288 2000
# 4      Allison McGregor              Exec. - Mktg.  (424) 288 2000
# ...                 ...                        ...             ...
# 1646        John Lochen                      Agent  (763) 999 7700
# 1647  Hendrik Wipperman             Agent (Europe)         #ERROR!
# 1648       Rachel Simon                      Agent  (763) 999 7700
# 1649      Diane Kinnear                         GM  (763) 999 7700
# 1650         Jen Chabot                Agent Asst.  (763) 999 7700
#
#                         Email            Street Address Street Address 2  \
# 0              rlight@caa.com  2000 Avenue of the Stars              NaN
# ...

# %%
agencies_df
# Out:
#                      33 and West  \
# 0               American Artists
# 1                Arrival Artists
# 2                  Atlas Touring
# 3       Blue Raven Entertainment
# 4        Brad Simon Organization
# ..                           ...
# 93            Swan Entertainment
# 94             The Empire Agency
# 95              The Roots Agency
# 96  Universal Attractions Agency
# 97                 M.O.B. Agency
#
#    https://www.pollstar.com/Company/33-west-109146004?tab=artistRoster&page=0  \
# 0   https://www.pollstar.com/Company/american-arti...
# 1   https://www.pollstar.com/Company/arrival-artis...
# 2   https://www.pollstar.com/Company/atlas-touring...
# 3   https://www.pollstar.com/Company/blue-raven-en...
# 4   https://www.pollstar.com/Company/the-brad-simo...
# ..                                                ...
# 93  https://www.pollstar.com/Company/swan-entertai...
# 94  https://www.pollstar.com/Company/the-empire-ag...
# ...

# %%
artists_df
# Out:
#         Artist Avg Tickets Gross Sales  \
# 0      5:00 AM         NaN         NaN
# 1           13         NaN         NaN
# 2           67         NaN         NaN
# 3          112       1,107     $87,099
# 4          112       1,107     $87,099
# ...        ...         ...         ...
# 16746     Zuli         230      $2,536
# 16747   ZutZut         NaN         NaN
# 16748     Zuzu         120      $1,161
# 16749   ZZ Top       4,784    $291,385
# 16750  ZZ Ward         694     $17,055
#
#                                                Territory  \
# 0                                          North America
# 1                                          North America
# 2                                          North America
# 3                                          non-exclusive
# 4                                          non-exclusive
# ...                                                  ...
# 16746                                          Worldwide
# ...

# %%
bands_df.head(50)
# Out:
#                          Artist Attendance          Gross Bands in Town
# 0                  Garth Brooks    102,500  $7,099,295.00         8,877
# 1                   Spice Girls     86,958  $9,750,672.00         2,678
# 2                    Ed Sheeran     84,092  $7,403,581.00        45,481
# 3                        Eminem     57,147  $6,243,147.00        76,068
# 4                       Beyoncé     55,617  $6,514,121.00        46,520
# 5                     Pearl Jam     52,075  $4,666,506.00        21,314
# 6                     Rammstein     46,599  $4,921,275.00         6,924
# 7                         Phish     36,441  $2,583,025.00         4,286
# 8                 George Strait     33,870  $5,353,168.00        20,442
# 9                         Drake     33,564  $3,969,774.00        78,872
# 10                   Bruno Mars     33,107  $4,591,266.00        57,728
# 11                Guns N' Roses     32,127  $3,478,993.00        25,979
# ...

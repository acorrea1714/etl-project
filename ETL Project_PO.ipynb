# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# %%
agents_df = pd.read_csv('Resources/agents.csv')
agencies_df = pd.read_csv('Resources/agencies.csv',names=["agency","agencyURL","NULL","NULL2"])
artists_df = pd.read_csv('Resources/artists.csv')
bands_df = pd.read_csv('Resources/bandsintown.csv', thousands=',')

# %%
agents_df
# Out:
#                   First                      Title    Phone Number  \
# 0             Rob Light  Worldwide - Head of Music  (424) 288 2000
# 1          Darryl Eaton      Co-Head of N. America  (424) 288 2000
# 2           Rick Roskin      Co-Head of N. America  (424) 288 2000
# 3            Mitch Rose      Co-Head of N. America  (424) 288 2000
# 4      Allison McGregor              Exec. - Mktg.  (424) 288 2000
# ...                 ...                        ...             ...
# 1646        John Lochen                      Agent  (763) 999 7700
# 1647  Hendrik Wipperman             Agent (Europe)         #ERROR!
# 1648       Rachel Simon                      Agent  (763) 999 7700
# 1649      Diane Kinnear                         GM  (763) 999 7700
# 1650         Jen Chabot                Agent Asst.  (763) 999 7700
#
#                         Email            Street Address Street Address 2  \
# 0              rlight@caa.com  2000 Avenue of the Stars              NaN
# 1              deaton@caa.com  2000 Avenue of the Stars              NaN
# 2             rroskin@caa.com  2000 Avenue of the Stars              NaN
# 3               mrose@caa.com  2000 Avenue of the Stars              NaN
# 4           amcgregor@caa.com  2000 Avenue of the Stars              NaN
# ...                       ...                       ...              ...
# 1646    john@nstarartists.com            P.O. Box 47393              NaN
# 1647    hendrik@eat-music.net            P.O. Box 47393              NaN
# 1648  rachel@nstarartists.com            P.O. Box 47393              NaN
# 1649   diane@nstarartists.com            P.O. Box 47393              NaN
# 1650     jen@nstarartists.com            P.O. Box 47393              NaN
#
#              City State    Zip                           Agency
# 0     Los Angeles    CA  90067  Creative Artists Agency (Music)
# 1     Los Angeles    CA  90067  Creative Artists Agency (Music)
# 2     Los Angeles    CA  90067  Creative Artists Agency (Music)
# 3     Los Angeles    CA  90067  Creative Artists Agency (Music)
# 4     Los Angeles    CA  90067  Creative Artists Agency (Music)
# ...           ...   ...    ...                              ...
# 1646  Minneapolis    MN  55447                 Northstar Artist
# 1647  Minneapolis    MN  55447                 Northstar Artist
# 1648  Minneapolis    MN  55447                 Northstar Artist
# 1649  Minneapolis    MN  55447                 Northstar Artist
# 1650  Minneapolis    MN  55447                 Northstar Artist
#
# [1651 rows x 10 columns]

# %%
agent_nameFrame = agents_df["First"].str.split(expand=True, n=1)

agents_df["firstName"] = agent_nameFrame[0]
agents_df["lastName"] = agent_nameFrame[1]
agents_df.drop(columns=['First'],inplace=True)

# %%
agents_df.reset_index(inplace=True)
agents_df = agents_df.rename(columns = {'index':'agentid'})


agents_df = pd.DataFrame({"agentid":agents_df["agentid"],
                         "firstname":agents_df['firstName'],
                         "lastname":agents_df['lastName'],
                         "title":agents_df['Title'],
                         "phone":agents_df["Phone Number"],
                         "email":agents_df["Email"],
                         "address1":agents_df['Street Address'],
                         "address2":agents_df['Street Address 2'],
                         "city":agents_df['City'],
                         "state":agents_df["State"],
                         "zip":agents_df["Zip"],
                         "agency":agents_df["Agency"]})

agents_df.drop_duplicates("agentid", inplace=True)
agents_df.set_index("agentid", inplace=True)

# %%
agents_df
# Out:
#         firstname   lastname                      title           phone  \
# agentid
# 0             Rob      Light  Worldwide - Head of Music  (424) 288 2000
# 1          Darryl      Eaton      Co-Head of N. America  (424) 288 2000
# 2            Rick     Roskin      Co-Head of N. America  (424) 288 2000
# 3           Mitch       Rose      Co-Head of N. America  (424) 288 2000
# 4         Allison   McGregor              Exec. - Mktg.  (424) 288 2000
# ...           ...        ...                        ...             ...
# 1646         John     Lochen                      Agent  (763) 999 7700
# 1647      Hendrik  Wipperman             Agent (Europe)         #ERROR!
# 1648       Rachel      Simon                      Agent  (763) 999 7700
# 1649        Diane    Kinnear                         GM  (763) 999 7700
# 1650          Jen     Chabot                Agent Asst.  (763) 999 7700
#
#                            email                  address1 address2  \
# agentid
# 0                 rlight@caa.com  2000 Avenue of the Stars      NaN
# 1                 deaton@caa.com  2000 Avenue of the Stars      NaN
# 2                rroskin@caa.com  2000 Avenue of the Stars      NaN
# 3                  mrose@caa.com  2000 Avenue of the Stars      NaN
# 4              amcgregor@caa.com  2000 Avenue of the Stars      NaN
# ...                          ...                       ...      ...
# 1646       john@nstarartists.com            P.O. Box 47393      NaN
# 1647       hendrik@eat-music.net            P.O. Box 47393      NaN
# 1648     rachel@nstarartists.com            P.O. Box 47393      NaN
# 1649      diane@nstarartists.com            P.O. Box 47393      NaN
# 1650        jen@nstarartists.com            P.O. Box 47393      NaN
#
#                 city state    zip                           agency
# agentid
# 0        Los Angeles    CA  90067  Creative Artists Agency (Music)
# 1        Los Angeles    CA  90067  Creative Artists Agency (Music)
# 2        Los Angeles    CA  90067  Creative Artists Agency (Music)
# 3        Los Angeles    CA  90067  Creative Artists Agency (Music)
# 4        Los Angeles    CA  90067  Creative Artists Agency (Music)
# ...              ...   ...    ...                              ...
# 1646     Minneapolis    MN  55447                 Northstar Artist
# 1647     Minneapolis    MN  55447                 Northstar Artist
# 1648     Minneapolis    MN  55447                 Northstar Artist
# 1649     Minneapolis    MN  55447                 Northstar Artist
# 1650     Minneapolis    MN  55447                 Northstar Artist
#
# [1651 rows x 11 columns]

# %%
agencies_df.drop(columns=["NULL","NULL2"],inplace=True)

# %%
agencies_df.reset_index(inplace=True)
agencies_df = agencies_df.rename(columns = {'index':'agencyid', 'agencyURL':'agencyurl'})

agencies_df.set_index("agencyid", inplace=True)

agencies_df
# Out:
#                                 agency  \
# agencyid
# 0                          33 and West
# 1                     American Artists
# 2                      Arrival Artists
# 3                        Atlas Touring
# 4             Blue Raven Entertainment
# ...                                ...
# 94                  Swan Entertainment
# 95                   The Empire Agency
# 96                    The Roots Agency
# 97        Universal Attractions Agency
# 98                       M.O.B. Agency
#
#                                                   agencyurl
# agencyid
# 0         https://www.pollstar.com/Company/33-west-10914...
# 1         https://www.pollstar.com/Company/american-arti...
# 2         https://www.pollstar.com/Company/arrival-artis...
# 3         https://www.pollstar.com/Company/atlas-touring...
# 4         https://www.pollstar.com/Company/blue-raven-en...
# ...                                                     ...
# 94        https://www.pollstar.com/Company/swan-entertai...
# 95        https://www.pollstar.com/Company/the-empire-ag...
# 96        https://www.pollstar.com/Company/the-roots-age...
# 97        https://www.pollstar.com/Company/uaa-universal...
# 98        https://www.pollstar.com/Company/the-mob-agenc...
#
# [99 rows x 2 columns]

# %%
artists_df.drop(columns=["Location"],inplace=True)

# %%
artists_df.reset_index(inplace=True)
artists_df = artists_df.rename(columns = {'index':'artistid'})

# %%
artists_df.rename(columns = {'Artist':'artist',"Avg Tickets":"attendance","Gross Sales":"averagegross","Territory":"territory","Agency":"agency"},inplace=True)
artists_df.set_index("artistid", inplace=True)

artists_df
# Out:
#            artist attendance averagegross  \
# artistid
# 0         5:00 AM        NaN          NaN
# 1              13        NaN          NaN
# 2              67        NaN          NaN
# 3             112      1,107      $87,099
# 4             112      1,107      $87,099
# ...           ...        ...          ...
# 16746        Zuli        230       $2,536
# 16747      ZutZut        NaN          NaN
# 16748        Zuzu        120       $1,161
# 16749      ZZ Top      4,784     $291,385
# 16750     ZZ Ward        694      $17,055
#
#                                                   territory  \
# artistid
# 0                                             North America
# 1                                             North America
# 2                                             North America
# 3                                             non-exclusive
# 4                                             non-exclusive
# ...                                                     ...
# 16746                                             Worldwide
# 16747     United States, Canada, United States, United S...
# 16748                                         North America
# 16749                                         North America
# 16750                                         North America
#
#                                    agency
# artistid
# 0                           Madison House
# 1                Paradigm - Beverly Hills
# 2                                     WME
# 3             Pyramid Entertainment Group
# 4            Universal Attractions Agency
# ...                                   ...
# 16746                                 APA
# 16747                     Surefire Agency
# 16748                      Paradigm - NYC
# 16749     Creative Artists Agency (Music)
# 16750                                 WME
#
# [16751 rows x 5 columns]

# %%
bands_df.drop(columns=["Attendance","Gross"],inplace=True)

# %%
bands_df.rename(columns={"Artist":"artist","Bands in Town":"bandsintown"},inplace=True)

# %%
# bands_df[['bandsintown']] = bands_df[['bandsintown']].apply(pd.to_numeric)
# bands_df = bands_df.sort_values(by=["bandsintown"],ascending=False)

# %%
# bands_df['bandsintown'] = bands_df["bandsintown"].replace('497361.0',0)
# bands_df.sort_values(by=['bandsintown'],ascending=False)

# %%
bands_df.sort_values(by=['bandsintown'],ascending=False)
# Out:
#                          artist  bandsintown
# 11558              Siobhan Bell     497361.0
# 12213          The Nearly Deads     497361.0
# 10546                      Off!     497361.0
# 11686                SOSUPERSAM     497361.0
# 11140     Rocket From The Crypt     497361.0
# ...                         ...          ...
# 179                   Leningrad          NaN
# 235    Pete Tong Ibiza Classics          NaN
# 13044                    ZutZut          NaN
# 13045                       NaN          NaN
# 13046                     13046          NaN
#
# [13047 rows x 2 columns]

# %%
bands_df.replace({497361.0:None,497354:None},inplace=True)

# %%
bands_df.sort_values(by=['bandsintown'],ascending=False)
# Out:
#             artist  bandsintown
# 9            Drake      78872.0
# 3           Eminem      76068.0
# 57      Katy Perry      63722.0
# 136      Lil Wayne      58351.0
# 10      Bruno Mars      57728.0
# ...            ...          ...
# 13036  Zero 7 (DJ)          NaN
# 13039   Zion Clark          NaN
# 13044       ZutZut          NaN
# 13045          NaN          NaN
# 13046        13046          NaN
#
# [13047 rows x 2 columns]

# %%
bands_df.reset_index(drop=True, inplace=True)
bands_df.set_index("artist", inplace=True)
bands_df
# Out:
#               bandsintown
# artist
# Garth Brooks       8877.0
# Spice Girls        2678.0
# Ed Sheeran        45481.0
# Eminem            76068.0
# Beyoncé           46520.0
# ...                   ...
# Zombi                78.0
# Zookëper             22.0
# ZutZut                NaN
# NaN                   NaN
# 13046                 NaN
#
# [13047 rows x 1 columns]

# %%
connection_string = "postgres:Alskdjfhg12$@localhost:5433/postgres"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-29-2d97e9123e98> in <module>
#       1 # Confirm tables
# ----> 2 engine.table_names()
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in table_names(self, schema, connection)
#    2317         """
#    2318
# -> 2319         with self._optional_conn_ctx_manager(connection) as conn:
#    2320             return self.dialect.get_table_names(conn, schema)
#    2321
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _optional_conn_ctx_manager(self, connection)
#    2087     def _optional_conn_ctx_manager(self, connection=None):
#    2088         if connection is None:
# -> 2089             with self._contextual_connect() as conn:
#    2090                 yield conn
#    2091         else:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2303         return self._connection_cls(
#    2304             self,
# -> 2305             self._wrap_pool_connect(self.pool.connect, None),
#    2306             close_with_result=close_with_result,
#    2307             **kwargs
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2341             if connection is None:
#    2342                 Connection._handle_dbapi_exception_noconnection(
# -> 2343                     e, dialect, self
#    2344                 )
#    2345             else:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1583         elif should_wrap:
#    1584             util.raise_(
# -> 1585                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1586             )
#    1587         else:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2337         dialect = self.dialect
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#    2341             if connection is None:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#      71         else:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#      71         else:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     491     def connect(self, *cargs, **cparams):
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#     495     def create_connect_args(self, url):
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
agents_df.to_sql(name='agent', con=engine, if_exists='append', index=True)
agencies_df.to_sql(name='agencies', con=engine, if_exists='append', index=True)
artists_df.to_sql(name='artists', con=engine, if_exists='append', index=True)
bands_df.to_sql(name='bands', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-30-aeb001cc7ce3> in <module>
# ----> 1 agents_df.to_sql(name='agent', con=engine, if_exists='append', index=True)
#       2 agencies_df.to_sql(name='agencies', con=engine, if_exists='append', index=True)
#       3 artists_df.to_sql(name='artists', con=engine, if_exists='append', index=True)
#       4 bands_df.to_sql(name='bands', con=engine, if_exists='append', index=True)
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1314             dtype=dtype,
#    1315         )
# -> 1316         table.create()
#    1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/sql.py in create(self)
#     642
#     643     def create(self):
# --> 644         if self.exists():
#     645             if self.if_exists == "fail":
#     646                 raise ValueError(f"Table '{self.name}' already exists.")
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/sql.py in exists(self)
#     629
#     630     def exists(self):
# --> 631         return self.pd_sql.has_table(self.name, self.schema)
#     632
#     633     def sql_schema(self):
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/sql.py in has_table(self, name, schema)
#    1339     def has_table(self, name, schema=None):
#    1340         return self.connectable.run_callable(
# -> 1341             self.connectable.dialect.has_table, name, schema or self.meta.schema
#    1342         )
#    1343
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in run_callable(self, callable_, *args, **kwargs)
#    2212
#    2213         """
# -> 2214         with self._contextual_connect() as conn:
#    2215             return conn.run_callable(callable_, *args, **kwargs)
#    2216
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2303         return self._connection_cls(
#    2304             self,
# -> 2305             self._wrap_pool_connect(self.pool.connect, None),
#    2306             close_with_result=close_with_result,
#    2307             **kwargs
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2341             if connection is None:
#    2342                 Connection._handle_dbapi_exception_noconnection(
# -> 2343                     e, dialect, self
#    2344                 )
#    2345             else:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1583         elif should_wrap:
#    1584             util.raise_(
# -> 1585                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1586             )
#    1587         else:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2337         dialect = self.dialect
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#    2341             if connection is None:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#      71         else:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#      71         else:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     491     def connect(self, *cargs, **cparams):
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#     495     def create_connect_args(self, url):
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
art_count = artists_df.groupby(by=['agency']).count()
art_count = art_count['artist'].sort_values(ascending=False)
art_count = art_count.to_frame()
art_count

html_artists = art_count.to_html() 
  
# # write html to file 
text_file = open("artist_count.html", "w") 
text_file.write(html_artists) 
text_file.close()

# %%
artists_df['attendance'] = artists_df['attendance'].replace(',', '')
artists_df['averagegross'] = artists_df['averagegross'].str.replace(',', '').str.replace('$', '')

# artists_df['attendance'].dtype

artists_df['averagegross'].dropna(inplace=True)
artists_df['averagegross']

artists_df['attendance'].dropna(inplace=True)
artists_df['attendance']

artist_clean = pd.DataFrame({"Artist":artists_df["artist"],"Attendance":artists_df["attendance"],"Avg Gross":artists_df['averagegross'],"Agency":artists_df["agency"]})

artist_clean.dropna(inplace=True)
agency_attendance = artist_clean.groupby(by=['Agency']).sum().sort_values(by=['Attendance'],ascending=False)

html = agency_attendance.to_html() 
  
# write html to file 
text_file = open("agency_attendance.html", "w") 
text_file.write(html) 
text_file.close()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-123-c1b9b85fa9b0> in <module>
# ----> 1 artist_df
#       2
#       3 # html = agency_attendance.to_html()
#       4
#       5 # # write html to file
#
# NameError: name 'artist_df' is not defined
